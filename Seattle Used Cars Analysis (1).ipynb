# %% [markdown]
# # Seattle Used Cars Analysis
# By Disha Vasa | Divison- C-16

# %%
# Project Setup
import pandas as pd

# %%
#
cars_df = pd.read_csv("seattle_car_fax_cleaned.csv")

# Print the first 5 rows
cars_df.head()
# Out:
#               model_full_name  year       brand   sub_model   value_type  \
# 0    2018 Kia Niro EX Premium  2018         Kia        Niro  great Value
# 1     2019 Volkswagen Jetta S  2019  Volkswagen       Jetta  great Value
# 2  2018 Toyota Highlander XLE  2018      Toyota  Highlander  great Value
# 3     2016 Subaru WRX Premium  2016      Subaru         WRX  great Value
# 4   2018 Jeep Wrangler Sahara  2018        Jeep    Wrangler  great Value
#
#         engine  miles  price
# 0  4 Cyl 1.6 L  41599  25735
# 1          NaN  11535  20797
# 2          NaN  56011  34290
# 3          NaN  82286  23995
# 4          NaN  18423  45380

# %% [markdown]
# # Part 1: Understanding our Dataset

# %%
cars_df
# Out:
#                               model_full_name  year          brand  \
# 0                    2018 Kia Niro EX Premium  2018            Kia
# 1                     2019 Volkswagen Jetta S  2019     Volkswagen
# 2                  2018 Toyota Highlander XLE  2018         Toyota
# 3                     2016 Subaru WRX Premium  2016         Subaru
# 4                   2018 Jeep Wrangler Sahara  2018           Jeep
# ...                                       ...   ...            ...
# 4995               2018 Mercedes-Benz CLA 250  2018  Mercedes-Benz
# 4996                    2019 Toyota Tacoma SR  2019         Toyota
# 4997  2019 Chevrolet Corvette Grand Sport LT2  2019      Chevrolet
# 4998                           2019 Audi A8 L  2019           Audi
# 4999                      2018 Ford F-150 XLT  2018           Ford
#
#        sub_model   value_type       engine  miles  price
# 0           Niro  great Value  4 Cyl 1.6 L  41599  25735
# ...

# %%
# Setting Pandas to Print All Rows always for every dataframe being printed
pd.set_option('display.max_rows', None)

# Print my entire cars df
cars_df.sort_values (["model_full_name", "miles"])
# Out:
#                                         model_full_name  year          brand  \
# 2040                      2000 Chevrolet Monte Carlo SS  2000      Chevrolet
# 2065                      2000 Chevrolet Monte Carlo SS  2000      Chevrolet
# 2090                      2000 Chevrolet Monte Carlo SS  2000      Chevrolet
# 2115                      2000 Chevrolet Monte Carlo SS  2000      Chevrolet
# 2140                      2000 Chevrolet Monte Carlo SS  2000      Chevrolet
# 2165                      2000 Chevrolet Monte Carlo SS  2000      Chevrolet
# 2190                      2000 Chevrolet Monte Carlo SS  2000      Chevrolet
# 2215                      2000 Chevrolet Monte Carlo SS  2000      Chevrolet
# 2240                      2000 Chevrolet Monte Carlo SS  2000      Chevrolet
# 2265                      2000 Chevrolet Monte Carlo SS  2000      Chevrolet
# 2290                      2000 Chevrolet Monte Carlo SS  2000      Chevrolet
# ...

# %%
# Count how many duplicates we have for every unique vehicle
dup_df = cars_df.groupby(["model_full_name", "miles"]).agg(total_occurences = ("model_full_name", "count"))

# Printing dup_df
dup_df.sort_values(["total_occurences"], ascending = False)
# Out:
#                                                            total_occurences
# model_full_name                                    miles
# 2014 Lexus IS 250                                  87066                 97
# 2000 Chevrolet Monte Carlo SS                      124225                72
# 2020 Chevrolet Trax LS                             5999                  72
# 2019 Chevrolet Colorado ZR2                        31332                 72
# 2018 Dodge Charger GT                              33433                 72
# 2019 Chevrolet Silverado 1500 LT Trail Boss        37677                 72
# 2020 Subaru Forester                               9703                  72
# 2019 Ford Ranger Lariat                            5670                  72
# 2020 Ford Mustang GT                               8306                  72
# 2019 Mercedes-Benz C-Class C 300                   32612                 72
# 2016 Chevrolet Camaro SS 1SS                       76831                 72
# ...

# %%
# Dropping the Duplicates
cars_df = cars_df.drop_duplicates(subset=["model_full_name", "miles"])
print("There are", len(cars_df), "used vehicles available at the Seattle Dealerships")
# Out:
# There are 612 used vehicles available at the Seattle Dealerships

# %% [markdown]
# # Market Analysis
#
# ### 1) Which brands of used cars are most available in Seattle?

# %%
brands_df = cars_df.groupby(["brand"]).agg(total_available = ("brand", "count"))
brands_df.sort_values(["total_available"], ascending = False)
# Out:
#                total_available
# brand
# Toyota                      81
# Ford                        62
# Chevrolet                   59
# Honda                       45
# Jeep                        38
# Volkswagen                  36
# Hyundai                     34
# Subaru                      33
# Kia                         31
# Mercedes-Benz               27
# Dodge                       17
# Audi                        15
# GMC                         15
# Ram                         13
# Acura                       13
# BMW                         13
# Lexus                       12
# Nissan                      11
# Infiniti                     9
# Mini                         8
# Land                         8
# Volvo                        8
# Buick                        5
# Mazda                        4
# Maserati                     3
# Tesla                        3
# Mitsubishi                   2
# Porsche                      2
# Jaguar                       2
# ...

# %% [markdown]
# ### 2. Which sub models of used cars are most available in Seattle?

# %%
sub_model_df = cars_df.groupby(["sub_model", "brand"]).agg(total_available = ("sub_model", "count"))
sub_model_df.sort_values(["total_available"], ascending = False).head (25)
# Out:
#                           total_available
# sub_model  brand
# Wrangler   Jeep                        15
# Civic      Honda                       14
# Tacoma     Toyota                      14
# Jetta      Volkswagen                  13
# Silverado  Chevrolet                   13
# Highlander Toyota                      13
# Grand      Jeep                        12
# Elantra    Hyundai                     12
# 4Runner    Toyota                      11
# Camry      Toyota                      10
# Escape     Ford                        10
# Accord     Honda                       10
# Tundra     Toyota                      10
# Passat     Volkswagen                   9
# RAV4       Toyota                       9
# F-150      Ford                         9
# Explorer   Ford                         9
# Tiguan     Volkswagen                   9
# Mustang    Ford                         8
# Cooper     Mini                         8
# Camaro     Chevrolet                    8
# ...

# %% [markdown]
# ### 3. Which specific models of used vehicles are available in Seattle?

# %%
model_df = cars_df.groupby(["model_full_name"]).agg(total_available = ("model_full_name", "count"))
model_df.sort_values(["total_available"], ascending = False)
# Out:
#                                                     total_available
# model_full_name
# 2019 Toyota Highlander XLE                                        7
# 2019 Volkswagen Jetta S                                           5
# 2019 Mercedes-Benz C-Class C 300                                  4
# 2018 Toyota 4Runner Limited Edition                               4
# 2019 Subaru Ascent Limited                                        4
# 2020 Volkswagen Passat R-Line                                     3
# 2019 Mini Cooper Countryman S                                     3
# 2018 Jeep Grand Cherokee Overland                                 3
# 2019 Subaru Crosstrek Limited                                     3
# 2018 Toyota Highlander XLE                                        3
# 2019 Volkswagen Tiguan SE                                         3
# 2018 Mercedes-Benz E-Class E 400                                  2
# 2019 Volvo XC90 T6 Momentum                                       2
# ...

# %%
model_df = cars_df.groupby(["year", "brand", "sub_model"]).agg(total_available = ("sub_model", "count"))
model_df.sort_values(["total_available"], ascending = False)
# Out:
#                                total_available
# year brand         sub_model
# 2019 Volkswagen    Jetta                    11
#      Toyota        Highlander                8
#                    Tacoma                    6
# 2018 Ford          Explorer                  5
# 2020 Volkswagen    Passat                    5
# 2018 BMW           3                         5
# 2019 Volkswagen    Tiguan                    5
#      Mini          Cooper                    5
# 2018 Toyota        4Runner                   5
#                    Highlander                5
#      Jeep          Grand                     5
#                    Wrangler                  5
#      Ford          Escape                    4
# 2017 Ford          Escape                    4
# 2019 Toyota        RAV4                      4
#      Chevrolet     Corvette                  4
# 2017 Hyundai       Tucson                    4
# 2018 Toyota        RAV4                      4
# ...

# %% [markdown]
# ### 4. What are the total vehicles for each value type?

# %%
value_type_df = cars_df.groupby(["value_type"]).agg(total_available = ("value_type", "count"))
value_type_df.sort_values(["total_available"], ascending = False)
# Out:
#              total_available
# value_type
# great Value              564
# good Value                45
# fair Value                 3

# %% [markdown]
# ### Which vehicles should we consider for purchase?
#
# **Criteria:** For a used car to qualify as a good purchase, it must:**
#
# - Have Driven Less than 45,000 miles
# - Be a Model in or after 2018
# - Have a value type of "great Value"
# - Civic, Corolla, 1500, Crosstrek, F-150, Tucson

# %%
shortlist_df = cars_df.loc[(cars_df["miles"]<=45000)
                          & (cars_df["year"]>=2018)
                          & (cars_df["value_type"] == "great Value")
                          & ((cars_df["sub_model"] == "Civic") |
                            (cars_df["sub_model"] == "Corolla") |
                            (cars_df["sub_model"] == "F-150") |
                            (cars_df["sub_model"] == "Crosstrek") |
                            (cars_df["sub_model"] == "Tucson") |
                            (cars_df["sub_model"] == "1500"))] 
                            
len(shortlist_df)
# Out:
# 26

# %%
shortlist_df.sort_values(["sub_model"])
# Out:
#                           model_full_name  year    brand  sub_model  \
# 5                   2019 Ram 1500 Laramie  2019      Ram       1500
# 315                 2020 Ram 1500 Limited  2020      Ram       1500
# 256                 2020 Ram 1500 Limited  2020      Ram       1500
# 177                 2019 Ram 1500 Laramie  2019      Ram       1500
# 310        2018 Honda Civic Sport Touring  2018    Honda      Civic
# 211              2018 Honda Civic Touring  2018    Honda      Civic
# 148                   2020 Honda Civic Si  2020    Honda      Civic
# 449        2021 Honda Civic Sport Touring  2021    Honda      Civic
# 455                2019 Honda Civic Sport  2019    Honda      Civic
# 19                    2018 Honda Civic EX  2018    Honda      Civic
# 14                    2019 Honda Civic Si  2019    Honda      Civic
# 137                2019 Honda Civic Sport  2019    Honda      Civic
# 349                2019 Toyota Corolla SE  2019   Toyota    Corolla
# ...

# %% [markdown]
# ## Finding the Best Honda Civic in the Market

# %%
shortlist_df = cars_df.loc[(cars_df["miles"]<=45000)
                          & (cars_df["year"]>=2018)
                          & (cars_df["value_type"] == "great Value")
                          & ((cars_df["sub_model"] == "Civic"))]

shortlist_df["miles_price_ratio"] = shortlist_df["miles"]/ shortlist_df["price"]

print("There are", len(shortlist_df), "used Honda Civics in the market that meet our criteria. They are:")
display(shortlist_df.sort_values(["miles_price_ratio", "miles"]))
# Out:
# There are 8 used Honda Civics in the market that meet our criteria. They are:
# <ipython-input-15-c9dcf5ffee3a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shortlist_df["miles_price_ratio"] = shortlist_df["miles"]/ shortlist_df["price"]
#                     model_full_name  year  brand sub_model   value_type  \
# 449  2021 Honda Civic Sport Touring  2021  Honda     Civic  great Value
# 148             2020 Honda Civic Si  2020  Honda     Civic  great Value
# 455          2019 Honda Civic Sport  2019  Honda     Civic  great Value
# 211        2018 Honda Civic Touring  2018  Honda     Civic  great Value
# 14              2019 Honda Civic Si  2019  Honda     Civic  great Value
# ...

# %% [markdown]
# ## Build a Report Maker Function That Accepts a Year, Brand, and Sub Model and creates a nice report

# %%
def get_report (year, brand, sub_model):
    
    # Printing the Vehicle Name
    print("Vehicle Name:", year, brand, sub_model)

    requests_df = cars_df.loc[(cars_df["year"] == year)
                             & (cars_df["brand"] == brand)
                             & (cars_df["sub_model"] == sub_model)]

    # Calculating the Total Available Cars, Median Miles of Available Cars, and Median Price of Available Cars
    
    print("Cars Available:", len(requests_df))
    print ("Median Miles:", requests_df["miles"].median())
    print("Median Price:", requests_df["price"].median())

    requests_df["miles_price_ratio"] = requests_df["miles"]/requests_df["price"]

    print("The available vehicles are:")
    display(requests_df)


    shortlist_df = requests_df.loc[(requests_df["miles"]<= 45000)
                                  & (requests_df["value_type"]=="great Value")]

    print("Our", len(shortlist_df), "recommendations are:")
    display(shortlist_df.sort_values(["miles_price_ratio"]))
    
    print("Prices to Miles Relationship Scatter Plot")
    requests_df.plot.scatter(x='miles', y='price', c='Red')

# %%
get_report(2019, "Toyota", "Highlander")
# Out:
# Vehicle Name: 2019 Toyota Highlander
# Cars Available: 8
# Median Miles: 18772.5
# Median Price: 39720.0
# The available vehicles are:
# <ipython-input-39-91a9cf9ec054>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   requests_df["miles_price_ratio"] = requests_df["miles"]/requests_df["price"]
#                  model_full_name  year   brand   sub_model   value_type  \
# 24    2019 Toyota Highlander XLE  2019  Toyota  Highlander  great Value
# 39    2019 Toyota Highlander XLE  2019  Toyota  Highlander  great Value
# 56    2019 Toyota Highlander XLE  2019  Toyota  Highlander  great Value
# 173   2019 Toyota Highlander XLE  2019  Toyota  Highlander  great Value
# 248    2019 Toyota Highlander SE  2019  Toyota  Highlander   good Value
# ...
